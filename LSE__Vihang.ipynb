# %% [markdown]
# <a href="https://colab.research.google.com/github/Vihang257/Oasis_Internship_Tasks/blob/main/LSE__Vihang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1ozqFX6grhaqdtqz7mZNcOW6U22BxfKZw_G9nCDaUkIE
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ozqFX6grhaqdtqz7mZNcOW6U22BxfKZw_G9nCDaUkIE
# From (redirected): https://docs.google.com/spreadsheets/d/1ozqFX6grhaqdtqz7mZNcOW6U22BxfKZw_G9nCDaUkIE/export?format=xlsx
# To: /content/Final_Election_Data (2004-2024).xlsx
# 198kB [00:00, 3.52MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/Final_Election_Data (2004-2024).xlsx')

# %%
df.head()
# Out:
#       PC Name Caste           State          Winning Candidate  \
# 0    Adilabad   GEN  Andhra Pradesh  Madhusudhan Reddy Takkala
# 1       Adoor   GEN          Kerala         Chengara Surendran
# 2        Agra   GEN   Uttar Pradesh                 Raj Babbar
# 3   Ahmedabad   GEN         Gujarat               Harin Pathak
# 4  Ahmednagar   GEN     Maharashtra   Gadakh Tukaram Gangadhar
#
#                         Party  Electors   Votes  Turnout  Margin  Margin %  \
# 0   Telangana Rashtra Samithi   1140834  830601     72.8   40974       4.9
# 1    Communist Party Of India    960122  682227     71.1   54534       8.0
# 2             Samajwadi Party   1430713  642675     44.9   57342       8.9
# 3       Bharatiya Janta Party   1382793  548391     39.7   77605      14.2
# 4  Nationalist Congress Party   1295593  686554     53.0   75077      10.9
#
#    Year
# 0  2004
# 1  2004
# 2  2004
# 3  2004
# 4  2004

# %% [markdown]
# TASK 1 : Electorate Size and Turnout Relationship

# %%
df24 = df[df['Year'] == 2024]
df24.head()
# Out:
#              PC Name Caste          State              Winning Candidate  \
# 2170        Adilabad    ST      Telangana                   Godam Nagesh
# 2171            Agra    SC  Uttar Pradesh          Prof S P Singh Baghel
# 2172      Ahmadnagar   GEN    Maharashtra          Nilesh Dnyandev Lanke
# 2173  Ahmedabad East   GEN        Gujarat  Hasmukhbhai Patel (H.S.PATEL)
# 2174  Ahmedabad West    SC        Gujarat  Dineshbhai Makwana (ADVOCATE)
#
#                                                  Party  Electors    Votes  \
# 2170                             Bharatiya Janta Party   1650175  1235597
# 2171                             Bharatiya Janta Party   2072685  1123779
# 2172  Nationalist Congress Party – Sharadchandra Pawar   1981866  1325477
# 2173                             Bharatiya Janta Party   2038162  1128339
# 2174                             Bharatiya Janta Party   1726987   966646
#
#       Turnout  Margin  Margin %  Year
# 2170     74.9   90652       7.3  2024
# 2171     54.2  271294      24.1  2024
# 2172     66.9   28929       2.2  2024
# 2173     55.4  461755      40.9  2024
# 2174     56.0  286437      29.6  2024

# %%
df2 = df24[['Electors','Turnout']].sort_values('Electors',ascending=True).reset_index(drop=True)
print(df2.head())
print(df2.tail())
# Out:
#    Electors  Turnout
# 0     57784     85.1
# 1    134189     68.9
# 2    184808     73.3
# 3    283024     72.6
# 4    315148     64.3
#      Electors  Turnout
# 538   2802580     68.5
# 539   2938370     57.0
# 540   2945487     49.9
# 541   3214496     54.5
# 542   3779596     51.2

# %%
df2_small = df2.loc[df2['Electors']<1000000]
df2_large = df2.loc[df2['Electors']>1000000]
print(df2_small.head())
print(df2_large.head())
# Out:
#    Electors  Turnout
# 0     57784     85.1
# 1    134189     68.9
# 2    184808     73.3
# 3    283024     72.6
# 4    315148     64.3
#     Electors  Turnout
# 15   1023699     78.9
# 16   1038027     76.8
# 17   1250157     67.2
# 18   1254823     66.6
# 19   1310529     72.6

# %%
'''sns.boxplot(df2_small['Turnout'].head(20))
plt.show()'''
# Out:
# "sns.boxplot(df2_small['Turnout'].head(20))\nplt.show()"

# %%
'''sns.boxplot(df2_large['Turnout'].head(20))
plt.show()'''
# Out:
# "sns.boxplot(df2_large['Turnout'].head(20))\nplt.show()"

# %%
print(df2_small['Turnout'].mean())
print(df2_large['Turnout'].mean())
# Out:
# 75.18
# 66.71704545454547

# %% [markdown]
# THERE IS SIGNIFICANT DIFFERENCE BETWEEN MEANS OF TURNOUT FOR SMALL SIZE OF ELECTORS AND LARGE SIZE OF ELECTORS. IT SEEMS NEGETIVELY CORRELATED

# %%
#plt.scatter(df2['Electors'],df2['Turnout'])
#plt.show()

# %%
sns.lineplot(x=df2['Electors'],y=df2['Turnout'])
plt.show()

# %%
df2['Turnout'].corr(df2['Electors'])
# Out:
# -0.38608055559451826

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
df19 = df[df['Year'] == 2019]
#df19.head()

# %%
df2_19 = df19[['Electors','Turnout']].sort_values('Electors',ascending=True).reset_index(drop=True)
print(df2.head())
print(df2.tail())
# Out:
#    Electors  Turnout
# 0     57784     85.1
# 1    134189     68.9
# 2    184808     73.3
# 3    283024     72.6
# 4    315148     64.3
#      Electors  Turnout
# 538   2802580     68.5
# 539   2938370     57.0
# 540   2945487     49.9
# 541   3214496     54.5
# 542   3779596     51.2

# %%
df2_19['Turnout'].corr(df2_19['Electors'])
# Out:
# -0.4607317707335803

# %% [markdown]
# THERE IS NEGATIVE CORRELATION OF -0.46 IN 2019 AND -0.38 IN 2024, THEREFORE TURNOUT DECRESES WITH INCREASE IN NUMBERS OF ELECTORS

# %%
#ALL YEARS
#df14 = df[df['Year'] == 2014]
#df2_14 = df14[['Electors','Turnout']].sort_values('Electors',ascending=True).reset_index(drop=True)
#df09 = df[df['Year'] == 2009]
#df2_09 = df09[['Electors','Turnout']].sort_values('Electors',ascending=True).reset_index(drop=True)

df2['Turnout'].corr(df2['Electors'])
# Out:
# -0.4679531565658976

# %% [markdown]
# TASK 2 : Turnout and Winning Candidate Analysis
#
# ---

# %%
df_24 = df[df['Year'] == 2024]
df_24.head()
# Out:
#              PC Name Caste          State              Winning Candidate  \
# 2170        Adilabad    ST      Telangana                   Godam Nagesh
# 2171            Agra    SC  Uttar Pradesh          Prof S P Singh Baghel
# 2172      Ahmadnagar   GEN    Maharashtra          Nilesh Dnyandev Lanke
# 2173  Ahmedabad East   GEN        Gujarat  Hasmukhbhai Patel (H.S.PATEL)
# 2174  Ahmedabad West    SC        Gujarat  Dineshbhai Makwana (ADVOCATE)
#
#                                                  Party  Electors    Votes  \
# 2170                             Bharatiya Janta Party   1650175  1235597
# 2171                             Bharatiya Janta Party   2072685  1123779
# 2172  Nationalist Congress Party – Sharadchandra Pawar   1981866  1325477
# 2173                             Bharatiya Janta Party   2038162  1128339
# 2174                             Bharatiya Janta Party   1726987   966646
#
#       Turnout  Margin  Margin %  Year
# 2170     74.9   90652       7.3  2024
# 2171     54.2  271294      24.1  2024
# 2172     66.9   28929       2.2  2024
# 2173     55.4  461755      40.9  2024
# 2174     56.0  286437      29.6  2024

# %%
df3 = df[['Turnout','Party','Votes']]
df3.head()
# Out:
#    Turnout                       Party   Votes
# 0     72.8   Telangana Rashtra Samithi  830601
# 1     71.1    Communist Party Of India  682227
# 2     44.9             Samajwadi Party  642675
# 3     39.7       Bharatiya Janta Party  548391
# 4     53.0  Nationalist Congress Party  686554

# %%
df3_24 = df_24[['Turnout','Party','Votes']]
df3_24.head()
# Out:
#       Turnout                                             Party    Votes
# 2170     74.9                             Bharatiya Janta Party  1235597
# 2171     54.2                             Bharatiya Janta Party  1123779
# 2172     66.9  Nationalist Congress Party – Sharadchandra Pawar  1325477
# 2173     55.4                             Bharatiya Janta Party  1128339
# 2174     56.0                             Bharatiya Janta Party   966646

# %%
df3_bjp = df3[df3['Party'] == 'Bharatiya Janta Party']
#df3_bjp.head()
# Out:
#     Turnout                  Party   Votes
# 3      39.7  Bharatiya Janta Party  548391
# 5      44.0  Bharatiya Janta Party  529138
# 7      57.8  Bharatiya Janta Party  734524
# 12     49.8  Bharatiya Janta Party  504756
# 19     55.1  Bharatiya Janta Party  711808

# %%
df3_inc = df3[df3['Party']=='Indian National Congress']
df3_inc.head()
# Out:
#     Turnout                     Party   Votes
# 8      47.2  Indian National Congress  633500
# 13     42.8  Indian National Congress  540451
# 14     77.7  Indian National Congress  702715
# 15     70.7  Indian National Congress  847673
# 16     44.5  Indian National Congress  589559

# %%
df3_others = df3[df3['Party']!='Bharatiya Janta Party']
df3_others.head()
# Out:
#    Turnout                       Party   Votes
# 0     72.8   Telangana Rashtra Samithi  830601
# 1     71.1    Communist Party Of India  682227
# 2     44.9             Samajwadi Party  642675
# 4     53.0  Nationalist Congress Party  686554
# 6     51.3         Bahujan Samaj Party  741543

# %%
print(df3['Turnout'].mean())
print(df3_bjp['Turnout'].mean())
print(df3_inc['Turnout'].mean())
print(df3_others['Turnout'].mean())
# Out:
# 64.77817913748618
# 63.09118738404453
# 64.37326007326008
# 65.89045871559632

# %%
print(df3['Turnout'].median())
print(df3_bjp['Turnout'].median())
print(df3_inc['Turnout'].median())
print(df3_others['Turnout'].median())
# Out:
# 64.9
# 62.849999999999994
# 66.0
# 67.2

# %%
df3_24bjp = df3_24[df3_24['Party'] == 'Bharatiya Janta Party']

# %%
df3_24others = df3_24[df3_24['Party']!='Bharatiya Janta Party']

# %%
print(df3_24['Turnout'].median())
print(df3_24bjp['Turnout'].median())
print(df3_24others['Turnout'].median())
# Out:
# 65.9
# 64.5
# 67.2

# %%
#print(df3_bjp['Votes'].mean())
#print(df3_others['Votes'].mean())

# %% [markdown]
# TURNOUT FOR CONSTITUENCIES WON BY BJP IS COMPARATIVELY LOWER THEN THAT WON BY OTHER PARTIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
retail_df = pd.read_csv('retail_sales_dataset.csv')

# %%
retail_df.head(5)
#retail_df.describe()
#retail_df.tail(5)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
retail_df['Date'] = pd.to_datetime(retail_df['Date'])
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB

# %%
retail_df.describe(include='object')
# Out:
#        Customer ID  Gender Product Category
# count         1000    1000             1000
# unique        1000       2                3
# top        CUST001  Female         Clothing
# freq             1     510              351

# %%
  retail_df['Product Category'].unique()
# Out:
# array(['Beauty', 'Clothing', 'Electronics'], dtype=object)

# %%
retail_df.isnull().sum(axis=0) #.sum() wthout specifying axis=0 gives same result
#there is no null in this data
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
retail_df.describe()
# Out:
#        Transaction ID                           Date         Age     Quantity  \
# count     1000.000000                           1000  1000.00000  1000.000000
# mean       500.500000  2023-07-03 00:25:55.200000256    41.39200     2.514000
# min          1.000000            2023-01-01 00:00:00    18.00000     1.000000
# 25%        250.750000            2023-04-08 00:00:00    29.00000     1.000000
# 50%        500.500000            2023-06-29 12:00:00    42.00000     3.000000
# 75%        750.250000            2023-10-04 00:00:00    53.00000     4.000000
# max       1000.000000            2024-01-01 00:00:00    64.00000     4.000000
# std        288.819436                            NaN    13.68143     1.132734
#
#        Price per Unit  Total Amount
# count     1000.000000   1000.000000
# mean       179.890000    456.000000
# min         25.000000     25.000000
# 25%         30.000000     60.000000
# 50%         50.000000    135.000000
# 75%        300.000000    900.000000
# ...

# %%
plt.boxplot(retail_df['Price per Unit'])
#retail_df['Price per Unit'].median()
#retail_df['Price per Unit'].mean()
#retail_df['Price per Unit'].quantile(0.25)
# Out:
# 30.0

# %%
plt.boxplot(retail_df['Total Amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x793718daba30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x793718dab4c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x793718dab700>],
#  'medians': [<matplotlib.lines.Line2D at 0x793718da94e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x793718da80d0>],
#  'means': []}

# %%
retail_df.loc[retail_df['Total Amount']==2000].count() #number of total amount '2000' out of 1000 data
retail_df.loc[(retail_df['Total Amount']>=1500)&~(retail_df['Total Amount']==2000)].count(). #number of total amount 'between 1500 and 2000' out of 1000 data
# Out:
# Transaction ID      50
# Date                50
# Customer ID         50
# Gender              50
# Age                 50
# Product Category    50
# Quantity            50
# Price per Unit      50
# Total Amount        50
# dtype: int64

# %%
retail_df
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# ...

# %%
df_bycategory = retail_df.groupby('Product Category')
df_bycategory['Quantity'].value_counts()
# Out:
# Product Category  Quantity
# Beauty            3           85
#                   2           75
#                   1           74
#                   4           73
# Clothing          4           97
#                   1           88
#                   3           86
#                   2           80
# Electronics       4           93
#                   1           91
#                   2           88
#                   3           70
# Name: count, dtype: int64

# %%
print('mean of Total Price :',retail_df['Total Amount'].mean())
print('mean of Price per Unit :',retail_df['Price per Unit'].mean())
print('median of Total Amount :',retail_df['Total Amount'].median())
print('median of Price per Unit :',retail_df['Price per Unit'].median())
# Out:
# mean of Total Price : 456.0
# mean of Price per Unit : 179.89
# median of Total Amount : 135.0
# median of Price per Unit : 50.0

# %%
print('Product Category wise mean :',retail_df.groupby('Product Category')['Price per Unit'].mean())
# Out:
# Product Category wise mean :/n Product Category
# Beauty         184.055375
# Clothing       174.287749
# Electronics    181.900585
# Name: Price per Unit, dtype: float64

# %%
print('Product Category wise median :',retail_df.groupby('Product Category')['Price per Unit'].median())
# Out:
# Product Category wise median : Product Category
# Beauty         50.0
# Clothing       50.0
# Electronics    50.0
# Name: Price per Unit, dtype: float64

# %%
print(retail_df.groupby('Product Category')['Total Amount'].mean())
print(retail_df.groupby('Product Category')['Total Amount'].count())
# Out:
# Product Category
# Beauty         467.475570
# Clothing       443.247863
# Electronics    458.786550
# Name: Total Amount, dtype: float64
# Product Category
# Beauty         307
# Clothing       351
# Electronics    342
# Name: Total Amount, dtype: int64

# %%
print(retail_df.groupby('Product Category')['Total Amount'].median())
# Out:
# Product Category
# Beauty         120.0
# Clothing       120.0
# Electronics    150.0
# Name: Total Amount, dtype: float64

# %%
retail_df['Total Amount'].mode()
# Out:
# 0    50
# Name: Total Amount, dtype: int64

# %%
print(retail_df['Date'].max())
print(retail_df['Date'].min())
# Out:
# 2024-01-01
# 2023-01-01

# %%
retail_df['month'] = retail_df['Date'].dt.month
retail_df.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount  month
# 0         3              50           150     11
# 1         2             500          1000      2
# 2         1              30            30      1
# 3         1             500           500      5
# 4         2              50           100      5

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=retail_df , x='month' , y='Total Amount')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Total Amount over Months')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=retail_df , x='month' , y='Total Amount' , hue='Product Category')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Total Amount over Months')
plt.show()

# %%
retail_df['Age_Category'] = pd.cut(retail_df['Age'] , bins=[17,30,40,50,64] , labels=['18-30','30-40','40-50','50-64'])
print(retail_df['Age_Category'].value_counts())
print(retail_df.loc[retail_df['Age_Category']=='50-64']['Total Amount'].mean())
#print(retail_df.loc[retail_df['Age_Cetagory']=='50-64']['Total Amount'].sum())
#print(retail_df.loc[retail_df['Age_Category']=='50-64']['Total Amount'].min())
print(retail_df.loc[retail_df['Age_Category']=='18-30']['Total Amount'].mean())
print(retail_df.loc[retail_df['Age_Category']=='30-40']['Total Amount'].mean())
print(retail_df.loc[retail_df['Age_Category']=='40-50']['Total Amount'].mean())
# Out:
# Age_Category
# 50-64    313
# 18-30    273
# 40-50    221
# 30-40    193
# Name: count, dtype: int64
# 425.9105431309904
# 486.97802197802196
# 497.1502590673575
# 424.4117647058824

# %%
#retail_df.loc[retail_df['Age_Catagory'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date, Customer ID, Gender, Age, Product Category, Quantity, Price per Unit, Total Amount, Age Catagory, Age_Catagory]
# Index: []

# %%
#sns.barplot(retail_df.groupby('Age')['Total Amount'].mean())
#print(retail_df.groupby('Age')['Total Amount'].mean())

# %%
sns.barplot(x=retail_df['Age_Category'] , y=retail_df['Total Amount'])
plt.title('Total Amount Average per Age Category')
# Out:
# Text(0.5, 1.0, 'Total Amount Average per Age Category')

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=retail_df , x='Age' , y='Total Amount')
plt.show()

# %%
sns.barplot(x=retail_df['Age_Category'] , y=retail_df['Quantity'])
plt.title('Average Quantity per Age Category')
# Out:
# Text(0.5, 1.0, 'Average Quantity per Age Category')

# %%
print(retail_df.groupby('Age_Category')['Total Amount'].mean())
print(retail_df.groupby('Age_Category')['Total Amount'].sum())
# Out:
# Age_Category
# 18-30    486.978022
# 30-40    497.150259
# 40-50    424.411765
# 50-64    425.910543
# Name: Total Amount, dtype: float64
# Age_Category
# 18-30    132945
# 30-40     95950
# 40-50     93795
# 50-64    133310
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(retail_df.groupby('Age_Category')['Total Amount'].sum())
plt.title('Total Sales Sum per Age Category')
# Out:
# Text(0.5, 1.0, 'Total Sales Sum per Age Category')

# %%
#retail_df.groupby(['Age_Category','Product Category'])['Total Amount'].count()
(retail_df.groupby(['Age_Category','Product Category'])['Total Amount'].count())/(retail_df.groupby('Age_Category')['Total Amount'].count())#percent of each category of products in different age categories
# Out:
# Age_Category  Product Category
# 18-30         Beauty              0.355311
#               Clothing            0.322344
#               Electronics         0.322344
# 30-40         Beauty              0.290155
#               Clothing            0.357513
#               Electronics         0.352332
# 40-50         Beauty              0.298643
#               Clothing            0.366516
#               Electronics         0.334842
# 50-64         Beauty              0.281150
#               Clothing            0.361022
#               Electronics         0.357827
# Name: Total Amount, dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.barplot(data=retail_df , x='Age_Category' , y='Total Amount' , hue='Product Category')
# Out:
# <Axes: xlabel='Age_Category', ylabel='Total Amount'>

# %%
plt.figure(figsize=(8,8))
sns.barplot(data=retail_df , y='Total Amount' , x='Product Category' , hue='Age_Category')
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Amount'>

# %%
#retail_df.groupby('Product Category')['Gender'].value_counts() #product category gender wise
#retail_df.groupby('Age_Category')['Gender'].value_counts()  #gender in each age category
# Out:
# Age_Category  Gender
# 18-30         Female    139
#               Male      134
# 30-40         Female     97
#               Male       96
# 40-50         Female    116
#               Male      105
# 50-64         Female    158
#               Male      155
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.barplot(data=retail_df , y='Total Amount' , x='Product Category' , hue='Gender')
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Amount'>

# %%
plt.figure(figsize=(5,5))
sns.barplot(retail_df.groupby('Gender')['Total Amount'].sum())
plt.title('Total Sales Sum Gender wise')
# Out:
# Text(0.5, 1.0, 'Total Sales Sum Gender wise')

# %%
plt.figure(figsize=(6,6))
sns.barplot(data=retail_df , x='Gender' , y='Total Amount' , hue='Product Category')
# Out:
# <Axes: xlabel='Gender', ylabel='Total Amount'>

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=retail_df , x='month' , y='Total Amount' , hue='Age_Category')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Total Amount over Months')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data=retail_df , x='month' , y='Total Amount' , hue='Gender')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Total Amount over Months')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=retail_df , x='month'  , hue='Gender')
plt.xlabel('Date')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=retail_df , x='month'  , hue='Age_Category')
plt.xlabel('Date')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=retail_df , x='month'  , hue='Product Category')
plt.xlabel('Date')
plt.show()
